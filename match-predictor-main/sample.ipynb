# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
import re
import time
# Out:
# https://www.premierleague.com/players/14732/Trent-Alexander-Arnold/stats/?co=1&se=418
#                          0                       1
# 0              Player name  Trent-Alexander-Arnold
# 1                     Team               Liverpool
# 2              Appearances                     150
# 3                    Goals                      10
# 4             Yellow cards                      14
# 5                Red cards                       0
# 6                    Fouls                      78
# 7                 Offsides                      20
# 8             Clean sheets                      50
# 9           Goals Conceded                     123
# 10                 Tackles                     236
# 11        Last man tackles                       3
# 12           Blocked shots                      -1
# 13           Interceptions                     188
# 14              Clearances                     251
# 15        Headed Clearance                      90
# ...
